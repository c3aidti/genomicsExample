# %%
import requests
import os
import pandas as pd
import json
import dateutil

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
}

base_url = "https://api.c3.ai/covid/api/1"

# %%
def fetch_data(url, headers=None, data=None):
    hasMore = True
    
    data['spec']['limit'] = -1
    data['spec']['offset'] = 0
    
    results = []
    
    while hasMore:
        r = requests.post(url,
                          headers=headers,
                          data=json.dumps(data))
        if r.status_code != 200:
            raise RuntimeError("Problem fetching data! {} ({})".format(r.text, r.request.body))
        
        res_json = json.loads(r.text)
        hasMore = res_json['hasMore']
        data['spec']['offset'] += res_json['count']
        
        results += res_json['objs']
    
    result_df = pd.DataFrame(results)
    result_df = result_df.set_index('id')
    return result_df

# %% [markdown]
# ## Data Exploration

# %%
data = {
    'spec': {
    }
}

bioasset_df = fetch_data(os.path.join(base_url, 'biologicalasset', 'fetch'),
                         headers=headers,
                         data=data)

# %%
nucleotideseq_df = bioasset_df[bioasset_df.assetType == 'nucleotide sequence']

# %%
dates = nucleotideseq_df.releaseDate.apply(lambda t: dateutil.parser.isoparse(t))

# %%
nucleotideseq_df
# Out:
#                       sequence            assetType sequenceType  \
# id
# 7BV2_P        {'id': '7BV2_P'}  nucleotide sequence      GenBank
# 7BV2_T        {'id': '7BV2_T'}  nucleotide sequence      GenBank
# LC522350    {'id': 'LC522350'}  nucleotide sequence      GenBank
# LC523807    {'id': 'LC523807'}  nucleotide sequence      GenBank
# LC523808    {'id': 'LC523808'}  nucleotide sequence      GenBank
# ...                        ...                  ...          ...
# MT612330    {'id': 'MT612330'}  nucleotide sequence      GenBank
# MT612331    {'id': 'MT612331'}  nucleotide sequence      GenBank
# MT612332    {'id': 'MT612332'}  nucleotide sequence      GenBank
# MT612333    {'id': 'MT612333'}  nucleotide sequence      GenBank
# NC_045512  {'id': 'NC_045512'}  nucleotide sequence       RefSeq
#
#                                                      species            genus  \
# id
# 7BV2_P     Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 7BV2_T     Severe acute respiratory syndrome-related coro...  Betacoronavirus
# LC522350   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# LC523807   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# LC523808   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# ...                                                      ...              ...
# MT612330   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT612331   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT612332   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT612333   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# NC_045512  Severe acute respiratory syndrome-related coro...  Betacoronavirus
#
#                   family                                            authors  \
# id
# 7BV2_P     Coronaviridae  Yin,W., Mao,C., Luan,X., Shen,D.D., Shen,Q., S...
# 7BV2_T     Coronaviridae  Yin,W., Mao,C., Luan,X., Shen,D.D., Shen,Q., S...
# LC522350   Coronaviridae  Nicolasora,A.D., Mercado,E.S., Polotan,F.M., M...
# LC523807   Coronaviridae  Mercado,E.S., Manalo,J.I., Nicolasora,A.D., Me...
# LC523808   Coronaviridae  Mercado,E.S., Manalo,J.I., Nicolasora,A.D., Me...
# ...                  ...                                                ...
# MT612330   Coronaviridae  Caly,L., Seemann,T., Sait,M., Schultz,M.B., Dr...
# MT612331   Coronaviridae  Caly,L., Seemann,T., Sait,M., Schultz,M.B., Dr...
# MT612332   Coronaviridae  Caly,L., Seemann,T., Sait,M., Schultz,M.B., Dr...
# MT612333   Coronaviridae  Caly,L., Seemann,T., Sait,M., Schultz,M.B., Dr...
# NC_045512  Coronaviridae  Baranov,P.V., Henderson,C.M., Anderson,C.B., G...
#
#                                                 genBankTitle  \
# id
# 7BV2_P     Chain P, The nsp12-nsp7-nsp8 complex bound to ...
# 7BV2_T                                     Chain T, Templete
# LC522350   Severe acute respiratory syndrome coronavirus ...
# LC523807   Severe acute respiratory syndrome coronavirus ...
# LC523808   Severe acute respiratory syndrome coronavirus ...
# ...                                                      ...
# MT612330   Severe acute respiratory syndrome coronavirus ...
# MT612331   Severe acute respiratory syndrome coronavirus ...
# MT612332   Severe acute respiratory syndrome coronavirus ...
# MT612333   Severe acute respiratory syndrome coronavirus ...
# NC_045512  Severe acute respiratory syndrome coronavirus ...
#
#                     releaseDate  \
# id
# 7BV2_P     2020-04-22T00:00:00Z
# 7BV2_T     2020-04-22T00:00:00Z
# LC522350   2020-02-08T00:00:00Z
# LC523807   2020-02-13T00:00:00Z
# LC523808   2020-02-13T00:00:00Z
# ...                         ...
# MT612330   2020-06-15T00:00:00Z
# MT612331   2020-06-15T00:00:00Z
# MT612332   2020-06-15T00:00:00Z
# MT612333   2020-06-15T00:00:00Z
# NC_045512  2020-01-13T00:00:00Z
#
#                                                         meta  version  \
# id
# 7BV2_P     {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# 7BV2_T     {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# LC522350   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# LC523807   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# LC523808   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# ...                                                      ...      ...
# MT612330   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT612331   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT612332   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT612333   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# NC_045512  {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
#
#                            publications                      location  \
# id
# 7BV2_P                         32358203                           NaN
# 7BV2_T                         32358203                           NaN
# LC522350                            NaN         {'id': 'Philippines'}
# LC523807                            NaN         {'id': 'Philippines'}
# LC523808                            NaN         {'id': 'Philippines'}
# ...                                 ...                           ...
# MT612330                            NaN  {'id': 'Victoria_Australia'}
# MT612331                            NaN  {'id': 'Victoria_Australia'}
# MT612332                            NaN  {'id': 'Victoria_Australia'}
# MT612333                            NaN  {'id': 'Victoria_Australia'}
# NC_045512  15680415, 15630477, 10482585               {'id': 'China'}
#
#           nucleotideCompleteness          host        collectionDate  \
# id
# 7BV2_P                       NaN           NaN                   NaN
# 7BV2_T                       NaN           NaN                   NaN
# LC522350                     NaN  Homo sapiens  2020-01-26T00:00:00Z
# LC523807                     NaN  Homo sapiens  2020-02-06T00:00:00Z
# LC523808                     NaN  Homo sapiens  2020-01-26T00:00:00Z
# ...                          ...           ...                   ...
# MT612330                     NaN  Homo sapiens  2020-05-26T00:00:00Z
# MT612331                     NaN  Homo sapiens  2020-05-26T00:00:00Z
# MT612332                     NaN  Homo sapiens  2020-05-26T00:00:00Z
# MT612333                     NaN  Homo sapiens  2020-05-26T00:00:00Z
# NC_045512                    NaN  Homo sapiens  2019-12-01T00:00:00Z
#
#           isolationSource bioSample
# id
# 7BV2_P                NaN       NaN
# 7BV2_T                NaN       NaN
# LC522350              NaN       NaN
# LC523807              NaN       NaN
# LC523808              NaN       NaN
# ...                   ...       ...
# MT612330              NaN       NaN
# MT612331              NaN       NaN
# MT612332              NaN       NaN
# MT612333              NaN       NaN
# NC_045512             NaN       NaN
#
# [6201 rows x 18 columns]

# %%
def is_whole_genome(n):
    try:
        if 'complete genome' in n:
            return True
        else:
            return False
    except:
        return False

whole_genomes_df = nucleotideseq_df[nucleotideseq_df.genBankTitle.apply(is_whole_genome)]

# %%
whole_genomes_df = whole_genomes_df[whole_genomes_df.location.notna()]

# %%
china_whole_genomes_df = whole_genomes_df[whole_genomes_df.location.apply(lambda d: d['id']) == 'China']

# %%
len(china_whole_genomes_df)
# Out:
# 24

# %%
china_whole_genomes_df.sequence.apply(lambda)
# Out:
#                       sequence            assetType sequenceType  \
# id
# MN908947    {'id': 'MN908947'}  nucleotide sequence      GenBank
# MN975262    {'id': 'MN975262'}  nucleotide sequence      GenBank
# MN988668    {'id': 'MN988668'}  nucleotide sequence      GenBank
# MN988669    {'id': 'MN988669'}  nucleotide sequence      GenBank
# MT039874    {'id': 'MT039874'}  nucleotide sequence      GenBank
# MT079843    {'id': 'MT079843'}  nucleotide sequence      GenBank
# MT079844    {'id': 'MT079844'}  nucleotide sequence      GenBank
# MT079845    {'id': 'MT079845'}  nucleotide sequence      GenBank
# MT079846    {'id': 'MT079846'}  nucleotide sequence      GenBank
# MT079847    {'id': 'MT079847'}  nucleotide sequence      GenBank
# MT079848    {'id': 'MT079848'}  nucleotide sequence      GenBank
# MT079849    {'id': 'MT079849'}  nucleotide sequence      GenBank
# MT079850    {'id': 'MT079850'}  nucleotide sequence      GenBank
# MT079851    {'id': 'MT079851'}  nucleotide sequence      GenBank
# MT079852    {'id': 'MT079852'}  nucleotide sequence      GenBank
# MT079853    {'id': 'MT079853'}  nucleotide sequence      GenBank
# MT079854    {'id': 'MT079854'}  nucleotide sequence      GenBank
# MT093631    {'id': 'MT093631'}  nucleotide sequence      GenBank
# MT226610    {'id': 'MT226610'}  nucleotide sequence      GenBank
# MT396241    {'id': 'MT396241'}  nucleotide sequence      GenBank
# MT412134    {'id': 'MT412134'}  nucleotide sequence      GenBank
# MT510727    {'id': 'MT510727'}  nucleotide sequence      GenBank
# MT510728    {'id': 'MT510728'}  nucleotide sequence      GenBank
# NC_045512  {'id': 'NC_045512'}  nucleotide sequence       RefSeq
#
#                                                      species            genus  \
# id
# MN908947   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MN975262   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MN988668   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MN988669   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT039874   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079843   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079844   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079845   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079846   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079847   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079848   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079849   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079850   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079851   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079852   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079853   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT079854   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT093631   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT226610   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT396241   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT412134   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT510727   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# MT510728   Severe acute respiratory syndrome-related coro...  Betacoronavirus
# NC_045512  Severe acute respiratory syndrome-related coro...  Betacoronavirus
#
#                   family                                            authors  \
# id
# MN908947   Coronaviridae  Wu,F., Zhao,S., Yu,B., Chen,Y.M., Wang,W., Son...
# MN975262   Coronaviridae  Chan,J.F.-W., Yuan,S., Kok,K.H., To,K.K.-W., C...
# MN988668   Coronaviridae  Chen,L., Liu,W., Zhang,Q., Xu,K., Ye,G., Wu,W....
# MN988669   Coronaviridae  Chen,L., Liu,W., Zhang,Q., Xu,K., Ye,G., Wu,W....
# MT039874   Coronaviridae  Zhang,X.A., Fan,H., Qi,R.Z., Zheng,W., Zheng,K...
# MT079843   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079844   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079845   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079846   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079847   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079848   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079849   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079850   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079851   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079852   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079853   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT079854   Coronaviridae  Wang,X., Zhou,Q., He,Y., Liu,L., Ma,X., Wei,X....
# MT093631   Coronaviridae  Linlin,B., Lili,R., Shuran,G., Jiangning,L., F...
# MT226610   Coronaviridae  Xu,X., Liao,Y., Wang,L., Zhou,X., Xie,Z., Chen...
# MT396241   Coronaviridae  Sun,Y., Dian,Z., Xu,Y., Zhang,G., Fan,X., Zhan...
# MT412134   Coronaviridae  Li,X., Lu,S., Wu,B., Hu,X., Li,D., Huang,X., G...
# MT510727   Coronaviridae                             Guo,X., Zeng,L., Yu,Z.
# MT510728   Coronaviridae                             Guo,X., Zeng,L., Yu,Z.
# NC_045512  Coronaviridae  Baranov,P.V., Henderson,C.M., Anderson,C.B., G...
#
#                                                 genBankTitle  \
# id
# MN908947   Severe acute respiratory syndrome coronavirus ...
# MN975262   Severe acute respiratory syndrome coronavirus ...
# MN988668   Severe acute respiratory syndrome coronavirus ...
# MN988669   Severe acute respiratory syndrome coronavirus ...
# MT039874   Severe acute respiratory syndrome coronavirus ...
# MT079843   Severe acute respiratory syndrome coronavirus ...
# MT079844   Severe acute respiratory syndrome coronavirus ...
# MT079845   Severe acute respiratory syndrome coronavirus ...
# MT079846   Severe acute respiratory syndrome coronavirus ...
# MT079847   Severe acute respiratory syndrome coronavirus ...
# MT079848   Severe acute respiratory syndrome coronavirus ...
# MT079849   Severe acute respiratory syndrome coronavirus ...
# MT079850   Severe acute respiratory syndrome coronavirus ...
# MT079851   Severe acute respiratory syndrome coronavirus ...
# MT079852   Severe acute respiratory syndrome coronavirus ...
# MT079853   Severe acute respiratory syndrome coronavirus ...
# MT079854   Severe acute respiratory syndrome coronavirus ...
# MT093631   Severe acute respiratory syndrome coronavirus ...
# MT226610   Severe acute respiratory syndrome coronavirus ...
# MT396241   Severe acute respiratory syndrome coronavirus ...
# MT412134   Severe acute respiratory syndrome coronavirus ...
# MT510727   Severe acute respiratory syndrome coronavirus ...
# MT510728   Severe acute respiratory syndrome coronavirus ...
# NC_045512  Severe acute respiratory syndrome coronavirus ...
#
#                     releaseDate  \
# id
# MN908947   2020-01-12T00:00:00Z
# MN975262   2020-01-24T00:00:00Z
# MN988668   2020-01-28T00:00:00Z
# MN988669   2020-01-28T00:00:00Z
# MT039874   2020-04-11T00:00:00Z
# MT079843   2020-05-15T00:00:00Z
# MT079844   2020-05-15T00:00:00Z
# MT079845   2020-05-15T00:00:00Z
# MT079846   2020-05-15T00:00:00Z
# MT079847   2020-05-15T00:00:00Z
# MT079848   2020-05-15T00:00:00Z
# MT079849   2020-05-15T00:00:00Z
# MT079850   2020-05-15T00:00:00Z
# MT079851   2020-05-15T00:00:00Z
# MT079852   2020-05-15T00:00:00Z
# MT079853   2020-05-15T00:00:00Z
# MT079854   2020-05-15T00:00:00Z
# MT093631   2020-02-21T00:00:00Z
# MT226610   2020-03-20T00:00:00Z
# MT396241   2020-04-28T00:00:00Z
# MT412134   2020-04-30T00:00:00Z
# MT510727   2020-05-26T00:00:00Z
# MT510728   2020-05-26T00:00:00Z
# NC_045512  2020-01-13T00:00:00Z
#
#                                                         meta  version  \
# id
# MN908947   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MN975262   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MN988668   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MN988669   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT039874   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079843   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079844   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079845   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079846   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079847   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079848   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079849   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079850   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079851   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079852   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079853   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT079854   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT093631   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT226610   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT396241   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT412134   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT510727   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# MT510728   {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
# NC_045512  {'tenantTagId': 4, 'tenant': 'covid', 'tag': '...        1
#
#                            publications         location  \
# id
# MN908947                       32015508  {'id': 'China'}
# MN975262                            NaN  {'id': 'China'}
# MN988668                            NaN  {'id': 'China'}
# MN988669                            NaN  {'id': 'China'}
# MT039874                       32222421  {'id': 'China'}
# MT079843                       32366488  {'id': 'China'}
# MT079844                       32366488  {'id': 'China'}
# MT079845                       32366488  {'id': 'China'}
# MT079846                       32366488  {'id': 'China'}
# MT079847                       32366488  {'id': 'China'}
# MT079848                       32366488  {'id': 'China'}
# MT079849                       32366488  {'id': 'China'}
# MT079850                       32366488  {'id': 'China'}
# MT079851                       32366488  {'id': 'China'}
# MT079852                       32366488  {'id': 'China'}
# MT079853                       32366488  {'id': 'China'}
# MT079854                       32366488  {'id': 'China'}
# MT093631                            NaN  {'id': 'China'}
# MT226610                            NaN  {'id': 'China'}
# MT396241                            NaN  {'id': 'China'}
# MT412134                            NaN  {'id': 'China'}
# MT510727                            NaN  {'id': 'China'}
# MT510728                            NaN  {'id': 'China'}
# NC_045512  15680415, 15630477, 10482585  {'id': 'China'}
#
#           nucleotideCompleteness          host        collectionDate  \
# id
# MN908947                     NaN  Homo sapiens  2019-12-01T00:00:00Z
# MN975262                     NaN  Homo sapiens  2020-01-11T00:00:00Z
# MN988668                     NaN  Homo sapiens  2020-01-02T00:00:00Z
# MN988669                     NaN  Homo sapiens  2020-01-02T00:00:00Z
# MT039874                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079843                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079844                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079845                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079846                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079847                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079848                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079849                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079850                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079851                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079852                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079853                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT079854                     NaN  Homo sapiens  2020-01-22T00:00:00Z
# MT093631                     NaN  Homo sapiens  2020-01-08T00:00:00Z
# MT226610                     NaN  Homo sapiens  2020-01-20T00:00:00Z
# MT396241                     NaN           NaN  2020-03-06T00:00:00Z
# MT412134                     NaN  Homo sapiens  2020-02-24T00:00:00Z
# MT510727                     NaN  Homo sapiens  2020-02-15T00:00:00Z
# MT510728                     NaN  Homo sapiens  2020-02-13T00:00:00Z
# NC_045512                    NaN  Homo sapiens  2019-12-01T00:00:00Z
#
#                 isolationSource bioSample
# id
# MN908947                    NaN       NaN
# MN975262   lung, oronasopharynx       NaN
# MN988668                    NaN       NaN
# MN988669                    NaN       NaN
# MT039874                    NaN       NaN
# MT079843                    NaN       NaN
# MT079844                    NaN       NaN
# MT079845                    NaN       NaN
# MT079846                    NaN       NaN
# MT079847                    NaN       NaN
# MT079848                    NaN       NaN
# MT079849                    NaN       NaN
# MT079850                    NaN       NaN
# MT079851                    NaN       NaN
# MT079852                    NaN       NaN
# MT079853                    NaN       NaN
# MT079854                    NaN       NaN
# MT093631         oronasopharynx       NaN
# MT226610         oronasopharynx       NaN
# MT396241                    NaN       NaN
# MT412134                    NaN       NaN
# MT510727                    NaN       NaN
# MT510728                    NaN       NaN
# NC_045512                   NaN       NaN

# %%
# Fetch sequences directly from Datalake restricted to China complete genomes

data = {
    'spec': {
        'filter': '(location.id == "China") && contains(genBankTitle, "complete genome")',
        'include': 'sequence.sequence'
    }
}

df = fetch_data(os.path.join(base_url, 'biologicalasset', 'fetch'),
                         headers=headers,
                         data=data)
df['raw_sequence'] = df.sequence.apply(lambda s: s['sequence'])

# %% [markdown]
# ## Saving sequences to FASTA file

# %%
# Write to fasta
def write_sequences_to_fasta(filename, df):
    with open(filename, 'w') as file:
        def write_sequence(r):
            file.write('>{}\n'.format(r.name))
            file.write('{}\n'.format(r.raw_sequence))
        df.apply(write_sequence, axis=1)

fasta_file = 'china_whole_genomes_short.fa'
write_sequences_to_fasta(fasta_file, df.iloc[:4])

# %% [markdown]
# ## Run Clustalw multi-sequence alignment

# %%
import subprocess

# %%
from Bio.Align.Applications import ClustalwCommandline
import subprocess
aligned_file = 'china_whole_genomes_short.phy'
clustalw_cline = ClustalwCommandline("clustalw2", align=True, infile=fasta_file, type='dna', outfile=aligned_file, output='phylip')
# !{str(clustalw_cline)}
# Out:
#  CLUSTAL 2.1 Multiple Sequence Alignments
#
#
# Sequence type explicitly set to DNA
# Sequence format is Pearson
# Sequence 1: MN908947   29903 bp
# Sequence 2: MN975262   29891 bp
# Sequence 3: MN988668   29881 bp
# Sequence 4: MN988669   29881 bp
# Start of Pairwise alignments
# Aligning...
#
# Sequences (1:2) Aligned. Score:  99
# Sequences (1:3) Aligned. Score:  100
# Sequences (1:4) Aligned. Score:  100
# Sequences (2:3) Aligned. Score:  99
# Sequences (2:4) Aligned. Score:  99
# Sequences (3:4) Aligned. Score:  100
# Guide tree file created:   [china_whole_genomes_short.dnd]
#
# There are 3 groups
# Start of Multiple Alignment
#
# Aligning...
# Group 1: Sequences:   2      Score:567739
# Group 2: Sequences:   3      Score:567739
# Group 3: Sequences:   4      Score:567754
# Alignment Score 1197212
#
# PHYLIP-Alignment file created   [china_whole_genomes_short.phy]

# %% [markdown]
# ## Now we generate the Phylogenetic Tree

# %%
from Bio import AlignIO, SeqIO
from phylogenetics import PhylogeneticsProject
from ete3 import PhyloTree, Tree

# %%
# Phylogenetics tree
# --------------------------------------------------------
# Initialize a project class
# You can change the output_dir
project = PhylogeneticsProject(project_dir='project', overwrite=True)

# Read alignments into the project, change schema according to your file format
# @path: your relative path to the aligned sequences file
# @schema: file format
#project.read_data(path='clustalo_1.phylip', schema='phylip')
project.read_data(path=aligned_file, schema='phylip')

# Run compute_tree
project.compute_tree(datatype='nt', model='HKY85')

# %%
def get_species_name(uid):
    import pandas as pd
    try:
        d = project.data.set_index('uid').loc[uid, 'description']
        if pd.isna(d):
            return uid
        else:
            return d
    except Exception as e:
        return uid

# Read the tree we constructed
t = PhyloTree(newick='project/compute_tree.phy_phyml_tree.txt',
              sp_naming_function=get_species_name)

# %%
print(t.get_ascii(attributes=['species']))
# Out:
#    /-MN908947
#   |
# --|--MN975262
#   |
#   |   /-MN988669
#    \-|
#       \-MN988668
